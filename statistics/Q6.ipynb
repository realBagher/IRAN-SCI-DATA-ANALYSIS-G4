# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler

# %%
data_r_cost_1398_s1 = pd.read_excel('R98.xlsx', sheet_name='R98P3S01')
data_r_cost_1398_s2 = pd.read_excel('R98.xlsx', sheet_name='R98P3S02')
data_r_cost_1398_s4 = pd.read_excel('R98.xlsx', sheet_name='R98P3S04')
data_r_cost_1398_s13 = pd.read_excel('R98.xlsx', sheet_name='R98P3S13')

# %%
median_1398_s1 = data_r_cost_1398_s1.groupby('Address').agg({'value': 'sum'}).median()
median_1398_s2 = data_r_cost_1398_s2.groupby('Address').agg({'value': 'sum'}).median()
median_1398_s4 = data_r_cost_1398_s4.groupby('Address').agg({'value': 'sum'}).median()

# %%
data_r_cost_1398_s13['value'] = data_r_cost_1398_s13['value'].astype(str).str.lstrip('0')
data_r_cost_1398_s13 = data_r_cost_1398_s13[(data_r_cost_1398_s13['value'].str.isdigit())]
data_r_cost_1398_s13['value'] = data_r_cost_1398_s13['value'].astype('int64')
median_1398_s13 = data_r_cost_1398_s13.groupby('Address').agg({'value': 'sum'}).median()

# %%
base_year_cost = median_1398_s1 + median_1398_s2 + median_1398_s4 + median_1398_s13

# %%
data_r_cost_1399_s1 = pd.read_excel('R99.xlsx', sheet_name='R99P3S01')
data_r_cost_1399_s2 = pd.read_excel('R99.xlsx', sheet_name='R99P3S02')
data_r_cost_1399_s4 = pd.read_excel('R99.xlsx', sheet_name='R99P3S04')
data_r_cost_1399_s13 = pd.read_excel('R99.xlsx', sheet_name='R99P3S13')

# %%
median_1399_s1 = data_r_cost_1399_s1.groupby('Address').agg({'value': 'sum'}).median()
median_1399_s2 = data_r_cost_1399_s2.groupby('Address').agg({'value': 'sum'}).median()
median_1399_s4 = data_r_cost_1399_s4.groupby('Address').agg({'value': 'sum'}).median()

# %%
data_r_cost_1399_s13['value'] = data_r_cost_1399_s13['value'].astype(str).str.lstrip('0')
data_r_cost_1399_s13 = data_r_cost_1399_s13[(data_r_cost_1399_s13['value'].str.isdigit())]
data_r_cost_1399_s13['value'] = data_r_cost_1399_s13['value'].astype('int64')
median_1399_s13 = data_r_cost_1399_s13.groupby('Address').agg({'value': 'sum'}).median()

# %%
year_1399_cost = median_1399_s1 + median_1399_s2 + median_1399_s4 + median_1399_s13

# %%
data_r_cost_1400_s1 = pd.read_excel('R1400.xlsx', sheet_name='R1400P3S01')
data_r_cost_1400_s2 = pd.read_excel('R1400.xlsx', sheet_name='R1400P3S02')
data_r_cost_1400_s4 = pd.read_excel('R1400.xlsx', sheet_name='R1400P3S04')
data_r_cost_1400_s13 = pd.read_excel('R1400.xlsx', sheet_name='R1400P3S13')

# %%
median_1400_s1 = data_r_cost_1400_s1.groupby('Address').agg({'value': 'sum'}).median()
median_1400_s2 = data_r_cost_1400_s2.groupby('Address').agg({'value': 'sum'}).median()
median_1400_s4 = data_r_cost_1400_s4.groupby('Address').agg({'value': 'sum'}).median()

# %%
data_r_cost_1400_s13['value'] = data_r_cost_1400_s13['value'].astype(str).str.lstrip('0')
data_r_cost_1400_s13 = data_r_cost_1400_s13[(data_r_cost_1400_s13['value'].str.isdigit())]
data_r_cost_1400_s13['value'] = data_r_cost_1400_s13['value'].astype('int64')

# %%
median_1400_s13 = data_r_cost_1400_s13.groupby('Address').agg({'value': 'sum'}).median()

# %%
year_1400_cost = median_1400_s1 + median_1400_s2 + median_1400_s4 + median_1400_s13

# %%
data_r_cost_1401_s1 = pd.read_excel('R1401.xlsx', sheet_name='R1401P3S01')
data_r_cost_1401_s2 = pd.read_excel('R1401.xlsx', sheet_name='R1401P3S02')
data_r_cost_1401_s4 = pd.read_excel('R1401.xlsx', sheet_name='R1401P3S04')
data_r_cost_1401_s13 = pd.read_excel('R1401.xlsx', sheet_name='R1401P3S13')

# %%
median_1401_s1 = data_r_cost_1401_s1.groupby('Address').agg({'value': 'sum'}).median()
median_1401_s2 = data_r_cost_1401_s2.groupby('Address').agg({'value': 'sum'}).median()
median_1401_s4 = data_r_cost_1401_s4.groupby('Address').agg({'value': 'sum'}).median()

# %%
data_r_cost_1401_s13['value'] = data_r_cost_1401_s13['value'].astype(str).str.lstrip('0')
data_r_cost_1401_s13 = data_r_cost_1401_s13[(data_r_cost_1401_s13['value'].str.isdigit())]
data_r_cost_1401_s13['value'] = data_r_cost_1401_s13['value'].astype('int64')
median_1401_s13 = data_r_cost_1401_s13.groupby('Address').agg({'value': 'sum'}).median()

# %%
year_1401_cost = median_1401_s1 + median_1401_s2 + median_1401_s4 + median_1401_s13

# %%
dt_azad1401_income = pd.read_excel('R1401.xlsx', sheet_name='R1401P4S02')

# %%
dt_azad1401_income= dt_azad1401_income[~(dt_azad1401_income['income_s_y'] == '              ')]
dt_azad1401_income.dropna(subset=['income_s_y'], inplace=True)
dt_azad1401_income['income_s_y'] = dt_azad1401_income['income_s_y'].astype('int64')
dt_azad1401_income_gp = dt_azad1401_income.groupby(['Address', 'member']).agg({'income_s_y': 'sum'})

# %%
dt_azad1401_income_gp = dt_azad1401_income_gp[~(dt_azad1401_income_gp['income_s_y'] < 0)]

# %%
dt_azad1401_income_gp.sort_values(by='income_s_y', inplace=True)
dt_azad1401_income_gp.reset_index(inplace=True)

# %%
dt_azad1400_income = pd.read_excel('R1400.xlsx', sheet_name='R1400P4S02')

# %%
dt_azad1400_income= dt_azad1400_income[~(dt_azad1400_income['income_s_y'] == '              ')]
dt_azad1400_income.dropna(subset=['income_s_y'], inplace=True)
dt_azad1400_income['income_s_y'] = dt_azad1400_income['income_s_y'].astype('int64')
dt_azad1400_income_gp = dt_azad1400_income.groupby(['Address', 'member']).agg({'income_s_y': 'sum'})

# %%
dt_azad1400_income_gp = dt_azad1400_income_gp[~(dt_azad1400_income_gp['income_s_y'] < 0)]

# %%
dt_azad1400_income_gp.sort_values(by='income_s_y', inplace=True)
dt_azad1400_income_gp.reset_index(inplace=True)

# %%
dt_azad1399_income = pd.read_excel('R99.xlsx', sheet_name='R99P4S02')

# %%
dt_azad1399_income= dt_azad1399_income[~(dt_azad1399_income['income_s_y'] == '              ')]
dt_azad1399_income.dropna(subset=['income_s_y'], inplace=True)
dt_azad1399_income['income_s_y'] = dt_azad1399_income['income_s_y'].astype('int64')
dt_azad1399_income_gp = dt_azad1399_income.groupby(['Address', 'member']).agg({'income_s_y': 'sum'})

# %%
dt_azad1399_income_gp = dt_azad1399_income_gp[~(dt_azad1399_income_gp['income_s_y'] < 0)]

# %%
dt_azad1399_income_gp.sort_values(by='income_s_y', inplace=True)
dt_azad1399_income_gp.reset_index(inplace=True)

# %%
dt_azad1398_income = pd.read_excel('R98.xlsx', sheet_name='R98P4S02')

# %%
dt_azad1398_income= dt_azad1398_income[~(dt_azad1398_income['income_s_y'] == '              ')]
dt_azad1398_income.dropna(subset=['income_s_y'], inplace=True)
dt_azad1398_income['income_s_y'] = dt_azad1398_income['income_s_y'].astype('int64')
dt_azad1398_income_gp = dt_azad1398_income.groupby(['Address', 'member']).agg({'income_s_y': 'sum'})

# %%
dt_azad1398_income_gp = dt_azad1398_income_gp[~(dt_azad1398_income_gp['income_s_y'] < 0)]

# %%
dt_azad1398_income_gp.sort_values(by='income_s_y', inplace=True)
dt_azad1398_income_gp.reset_index(inplace=True)

# %%
plt.figure(figsize=(10,5))
plt.plot(dt_azad1398_income_gp.index, dt_azad1398_income_gp['income_s_y'], label=1398)
plt.plot(dt_azad1399_income_gp.index, dt_azad1399_income_gp['income_s_y'], label=1399)
plt.plot(dt_azad1400_income_gp.index, dt_azad1400_income_gp['income_s_y'], label=1400)
plt.plot(dt_azad1401_income_gp.index, dt_azad1401_income_gp['income_s_y'], label=1401)
plt.tight_layout()
plt.legend()
plt.show()

# %%
dt_azad1398_income_gp['real_income'] = dt_azad1398_income_gp['income_s_y'] * (base_year_cost / base_year_cost).values[0]
dt_azad1399_income_gp['real_income'] = dt_azad1399_income_gp['income_s_y'] * (base_year_cost / year_1399_cost).values[0]
dt_azad1400_income_gp['real_income'] = dt_azad1400_income_gp['income_s_y'] * (base_year_cost / year_1400_cost).values[0]
dt_azad1401_income_gp['real_income'] = dt_azad1401_income_gp['income_s_y'] * (base_year_cost / year_1401_cost).values[0]

# %%
plt.figure(figsize=(10,5))
plt.plot(dt_azad1398_income_gp.index, dt_azad1398_income_gp['real_income'], label=1398)
plt.plot(dt_azad1399_income_gp.index, dt_azad1399_income_gp['real_income'], label=1399)
plt.plot(dt_azad1400_income_gp.index, dt_azad1400_income_gp['real_income'], label=1400)
plt.plot(dt_azad1401_income_gp.index, dt_azad1401_income_gp['real_income'], label=1401)
plt.tight_layout()
plt.legend()
plt.show()

# %%
dt_azad1401_income_gp_part1 = dt_azad1401_income_gp[dt_azad1401_income_gp['real_income'] < dt_azad1401_income_gp['real_income'].quantile(0.8)]
dt_azad1400_income_gp_part1 = dt_azad1400_income_gp[dt_azad1400_income_gp['real_income'] < dt_azad1400_income_gp['real_income'].quantile(0.8)]
dt_azad1399_income_gp_part1 = dt_azad1399_income_gp[dt_azad1399_income_gp['real_income'] < dt_azad1399_income_gp['real_income'].quantile(0.8)]
dt_azad1398_income_gp_part1 = dt_azad1398_income_gp[dt_azad1398_income_gp['real_income'] < dt_azad1398_income_gp['real_income'].quantile(0.8)]

# %%
fig ,ax = plt.subplots(2,1, figsize=(10,5))
ax = ax.flatten()

ax[0].plot(dt_azad1398_income_gp_part1.index, dt_azad1398_income_gp_part1['income_s_y'], label=1398)
ax[0].plot(dt_azad1399_income_gp_part1.index, dt_azad1399_income_gp_part1['income_s_y'], label=1399)
ax[0].plot(dt_azad1400_income_gp_part1.index, dt_azad1400_income_gp_part1['income_s_y'], label=1400)
ax[0].plot(dt_azad1401_income_gp_part1.index, dt_azad1401_income_gp_part1['income_s_y'], label=1401)
ax[0].legend()

ax[1].plot(dt_azad1398_income_gp_part1.index, dt_azad1398_income_gp_part1['real_income'], label=1398)
ax[1].plot(dt_azad1399_income_gp_part1.index, dt_azad1399_income_gp_part1['real_income'], label=1399)
ax[1].plot(dt_azad1400_income_gp_part1.index, dt_azad1400_income_gp_part1['real_income'], label=1400)
ax[1].plot(dt_azad1401_income_gp_part1.index, dt_azad1401_income_gp_part1['real_income'], label=1401)
ax[1].legend()
plt.show()

# %%
dt_mozd1401_income = pd.read_excel('R1401.xlsx', sheet_name='R1401P4S01')
dt_mozd1401_income_gp = dt_mozd1401_income.groupby(['Address', 'member']).agg({'netincome_w_y': 'sum'})
dt_mozd1401_income_gp.sort_values(by='netincome_w_y', inplace=True)
dt_mozd1401_income_gp.reset_index(inplace=True)

# %%
dt_mozd1400_income = pd.read_excel('R1400.xlsx', sheet_name='R1400P4S01')
dt_mozd1400_income_gp = dt_mozd1400_income.groupby(['Address', 'member']).agg({'netincome_w_y': 'sum'})
dt_mozd1400_income_gp.sort_values(by='netincome_w_y', inplace=True)
dt_mozd1400_income_gp.reset_index(inplace=True)

# %%
dt_mozd1399_income = pd.read_excel('R99.xlsx', sheet_name='R99P4S01')
dt_mozd1399_income_gp = dt_mozd1399_income.groupby(['Address', 'member']).agg({'netincome_w_y': 'sum'})
dt_mozd1399_income_gp.sort_values(by='netincome_w_y', inplace=True)
dt_mozd1399_income_gp.reset_index(inplace=True)

# %%
dt_mozd1398_income = pd.read_excel('R98.xlsx', sheet_name='R98P4S01')
dt_mozd1398_income_gp = dt_mozd1398_income.groupby(['Address', 'member']).agg({'netincome_w_y': 'sum'})
dt_mozd1398_income_gp.sort_values(by='netincome_w_y', inplace=True)
dt_mozd1398_income_gp.reset_index(inplace=True)

# %%
dt_mozd1398_income_gp['real_income'] = dt_mozd1398_income_gp['netincome_w_y'] * (base_year_cost / base_year_cost).values[0]
dt_mozd1399_income_gp['real_income'] = dt_mozd1399_income_gp['netincome_w_y'] * (base_year_cost / year_1399_cost).values[0]
dt_mozd1400_income_gp['real_income'] = dt_mozd1400_income_gp['netincome_w_y'] * (base_year_cost / year_1400_cost).values[0]
dt_mozd1401_income_gp['real_income'] = dt_mozd1401_income_gp['netincome_w_y'] * (base_year_cost / year_1401_cost).values[0]

# %%
plt.figure(figsize=(10,5))
plt.plot(dt_mozd1398_income_gp.index, dt_mozd1398_income_gp['netincome_w_y'], label=1398)
plt.plot(dt_mozd1399_income_gp.index, dt_mozd1399_income_gp['netincome_w_y'], label=1399)
plt.plot(dt_mozd1400_income_gp.index, dt_mozd1400_income_gp['netincome_w_y'], label=1400)
plt.plot(dt_mozd1401_income_gp.index, dt_mozd1401_income_gp['netincome_w_y'], label=1401)
plt.tight_layout()
plt.legend()
plt.show()

# %%
dt_mozd1401_income_gp = dt_mozd1401_income_gp[dt_mozd1401_income_gp['real_income'] < dt_mozd1401_income_gp['real_income'].quantile(0.8)]
dt_mozd1400_income_gp = dt_mozd1400_income_gp[dt_mozd1400_income_gp['real_income'] < dt_mozd1400_income_gp['real_income'].quantile(0.8)]
dt_mozd1399_income_gp = dt_mozd1399_income_gp[dt_mozd1399_income_gp['real_income'] < dt_mozd1399_income_gp['real_income'].quantile(0.8)]
dt_mozd1398_income_gp = dt_mozd1398_income_gp[dt_mozd1398_income_gp['real_income'] < dt_mozd1398_income_gp['real_income'].quantile(0.8)]

# %%
# plt.figure(figsize=(10,5))
fig ,ax = plt.subplots(2,1, figsize=(10,5))
ax = ax.flatten()
ax[0].plot(dt_mozd1398_income_gp.index, dt_mozd1398_income_gp['netincome_w_y'], label=1398)
ax[0].plot(dt_mozd1399_income_gp.index, dt_mozd1399_income_gp['netincome_w_y'], label=1399)
ax[0].plot(dt_mozd1400_income_gp.index, dt_mozd1400_income_gp['netincome_w_y'], label=1400)
ax[0].plot(dt_mozd1401_income_gp.index, dt_mozd1401_income_gp['netincome_w_y'], label=1401)
# ax[0].tight_layout()
ax[0].legend()

ax[1].plot(dt_mozd1398_income_gp.index, dt_mozd1398_income_gp['real_income'], label=1398)
ax[1].plot(dt_mozd1399_income_gp.index, dt_mozd1399_income_gp['real_income'], label=1399)
ax[1].plot(dt_mozd1400_income_gp.index, dt_mozd1400_income_gp['real_income'], label=1400)
ax[1].plot(dt_mozd1401_income_gp.index, dt_mozd1401_income_gp['real_income'], label=1401)
ax[1].legend()
plt.show()

# %%
data_u_cost_1398_s1 = pd.read_excel('U98.xlsx', sheet_name='U98P3S01')
data_u_cost_1398_s2 = pd.read_excel('U98.xlsx', sheet_name='U98P3S02')
data_u_cost_1398_s4 = pd.read_excel('U98.xlsx', sheet_name='U98P3S04')
data_u_cost_1398_s13 = pd.read_excel('U98.xlsx', sheet_name='U98P3S13')

# %%
median_1398_u_s1 = data_u_cost_1398_s1.groupby('Address').agg({'value': 'sum'}).median()
median_1398_u_s2 = data_u_cost_1398_s2.groupby('Address').agg({'value': 'sum'}).median()
median_1398_u_s4 = data_u_cost_1398_s4.groupby('Address').agg({'value': 'sum'}).median()

# %%
data_u_cost_1398_s13['value'] = data_u_cost_1398_s13['value'].astype(str).str.lstrip('0')
data_u_cost_1398_s13 = data_u_cost_1398_s13[(data_u_cost_1398_s13['value'].str.isdigit())]
data_u_cost_1398_s13['value'] = data_u_cost_1398_s13['value'].astype('int64')
median_1398_u_s13 = data_u_cost_1398_s13.groupby('Address').agg({'value': 'sum'}).median()

# %%
base_year_cost_u = median_1398_u_s1 + median_1398_u_s2 + median_1398_u_s4 + median_1398_u_s13

# %%
data_u_cost_1399_s1 = pd.read_excel('U99.xlsx', sheet_name='U99P3S01')
data_u_cost_1399_s2 = pd.read_excel('U99.xlsx', sheet_name='U99P3S02')
data_u_cost_1399_s4 = pd.read_excel('U99.xlsx', sheet_name='U99P3S04')
data_u_cost_1399_s13 = pd.read_excel('U99.xlsx', sheet_name='U99P3S13')

# %%
median_1399_u_s1 = data_u_cost_1399_s1.groupby('Address').agg({'value': 'sum'}).median()
median_1399_u_s2 = data_u_cost_1399_s2.groupby('Address').agg({'value': 'sum'}).median()
median_1399_u_s4 = data_u_cost_1399_s4.groupby('Address').agg({'value': 'sum'}).median()

# %%
data_u_cost_1399_s13['value'] = data_u_cost_1399_s13['value'].astype(str).str.lstrip('0')
data_u_cost_1399_s13 = data_u_cost_1399_s13[(data_u_cost_1399_s13['value'].str.isdigit())]
data_u_cost_1399_s13['value'] = data_u_cost_1399_s13['value'].astype('int64')
median_1399_u_s13 = data_u_cost_1399_s13.groupby('Address').agg({'value': 'sum'}).median()

# %%
year_1399_cost_u = median_1399_u_s1 + median_1399_u_s2 + median_1399_u_s4 + median_1399_u_s13

# %%
data_u_cost_1400_s1 = pd.read_excel('U1400.xlsx', sheet_name='U1400P3S01')
data_u_cost_1400_s2 = pd.read_excel('U1400.xlsx', sheet_name='U1400P3S02')
data_u_cost_1400_s4 = pd.read_excel('U1400.xlsx', sheet_name='U1400P3S04')
data_u_cost_1400_s13 = pd.read_excel('U1400.xlsx', sheet_name='U1400P3S13')

# %%
median_1400_u_s1 = data_u_cost_1400_s1.groupby('Address').agg({'value': 'sum'}).median()
median_1400_u_s2 = data_u_cost_1400_s2.groupby('Address').agg({'value': 'sum'}).median()
median_1400_u_s4 = data_u_cost_1400_s4.groupby('Address').agg({'value': 'sum'}).median()

# %%
data_u_cost_1400_s13['value'] = data_u_cost_1400_s13['value'].astype(str).str.lstrip('0')
data_u_cost_1400_s13 = data_u_cost_1400_s13[(data_u_cost_1400_s13['value'].str.isdigit())]
data_u_cost_1400_s13['value'] = data_u_cost_1400_s13['value'].astype('int64')

# %%
median_1400_u_s13 = data_u_cost_1400_s13.groupby('Address').agg({'value': 'sum'}).median()

# %%
year_1400_cost_u = median_1400_u_s1 + median_1400_u_s2 + median_1400_u_s4 + median_1400_u_s13

# %%
data_u_cost_1401_s1 = pd.read_excel('U1401.xlsx', sheet_name='U1401P3S01')
data_u_cost_1401_s2 = pd.read_excel('U1401.xlsx', sheet_name='U1401P3S02')
data_u_cost_1401_s4 = pd.read_excel('U1401.xlsx', sheet_name='U1401P3S04')
data_u_cost_1401_s13 = pd.read_excel('U1401.xlsx', sheet_name='U1401P3S13')

# %%
median_1401_u_s1 = data_u_cost_1401_s1.groupby('Address').agg({'value': 'sum'}).median()
median_1401_u_s2 = data_u_cost_1401_s2.groupby('Address').agg({'value': 'sum'}).median()
median_1401_u_s4 = data_u_cost_1401_s4.groupby('Address').agg({'value': 'sum'}).median()

# %%
data_u_cost_1401_s13['value'] = data_u_cost_1401_s13['value'].astype(str).str.lstrip('0')
data_u_cost_1401_s13 = data_u_cost_1401_s13[(data_u_cost_1401_s13['value'].str.isdigit())]
data_u_cost_1401_s13['value'] = data_u_cost_1401_s13['value'].astype('int64')
median_1401_u_s13 = data_u_cost_1401_s13.groupby('Address').agg({'value': 'sum'}).median()

# %%
year_1401_cost_u = median_1401_u_s1 + median_1401_u_s2 + median_1401_u_s4 + median_1401_u_s13

# %%
dt_azad1401_income_u = pd.read_excel('U1401.xlsx', sheet_name='U1401P4S02')

# %%
dt_azad1401_income_u = dt_azad1401_income_u[~(dt_azad1401_income_u['income_s_y'] == '              ')]
dt_azad1401_income_u.dropna(subset=['income_s_y'], inplace=True)
dt_azad1401_income_u['income_s_y'] = dt_azad1401_income_u['income_s_y'].astype('int64')
dt_azad1401_income_u_gp = dt_azad1401_income_u.groupby(['Address', 'member']).agg({'income_s_y': 'sum'})

# %%
dt_azad1401_income_u_gp = dt_azad1401_income_u_gp[~(dt_azad1401_income_u_gp['income_s_y'] < 0)]

# %%
dt_azad1401_income_u_gp.sort_values(by='income_s_y', inplace=True)
dt_azad1401_income_u_gp.reset_index(inplace=True)

# %%
dt_azad1400_income_u = pd.read_excel('U1400.xlsx', sheet_name='U1400P4S02')

# %%
dt_azad1400_income_u= dt_azad1400_income_u[~(dt_azad1400_income_u['income_s_y'] == '              ')]
dt_azad1400_income_u.dropna(subset=['income_s_y'], inplace=True)
dt_azad1400_income_u['income_s_y'] = dt_azad1400_income_u['income_s_y'].astype('int64')
dt_azad1400_income_u_gp = dt_azad1400_income_u.groupby(['Address', 'member']).agg({'income_s_y': 'sum'})

# %%
dt_azad1400_income_u_gp = dt_azad1400_income_u_gp[~(dt_azad1400_income_u_gp['income_s_y'] < 0)]

# %%
dt_azad1400_income_u_gp.sort_values(by='income_s_y', inplace=True)
dt_azad1400_income_u_gp.reset_index(inplace=True)

# %%
dt_azad1399_income_u = pd.read_excel('U99.xlsx', sheet_name='U99P4S02')

# %%
dt_azad1399_income_u= dt_azad1399_income_u[~(dt_azad1399_income_u['income_s_y'] == '              ')]
dt_azad1399_income_u.dropna(subset=['income_s_y'], inplace=True)
dt_azad1399_income_u['income_s_y'] = dt_azad1399_income_u['income_s_y'].astype('int64')
dt_azad1399_income_u_gp = dt_azad1399_income_u.groupby(['Address', 'member']).agg({'income_s_y': 'sum'})

# %%
dt_azad1399_income_u_gp = dt_azad1399_income_u_gp[~(dt_azad1399_income_u_gp['income_s_y'] < 0)]

# %%
dt_azad1399_income_u_gp.sort_values(by='income_s_y', inplace=True)
dt_azad1399_income_u_gp.reset_index(inplace=True)

# %%
dt_azad1398_income_u = pd.read_excel('U98.xlsx', sheet_name='U98P4S02')

# %%
dt_azad1398_income_u= dt_azad1398_income_u[~(dt_azad1398_income_u['income_s_y'] == '              ')]
dt_azad1398_income_u.dropna(subset=['income_s_y'], inplace=True)
dt_azad1398_income_u['income_s_y'] = dt_azad1398_income_u['income_s_y'].astype('int64')
dt_azad1398_income_u_gp = dt_azad1398_income_u.groupby(['Address', 'member']).agg({'income_s_y': 'sum'})

# %%
dt_azad1398_income_u_gp = dt_azad1398_income_u_gp[~(dt_azad1398_income_u_gp['income_s_y'] < 0)]

# %%
dt_azad1398_income_u_gp.sort_values(by='income_s_y', inplace=True)
dt_azad1398_income_u_gp.reset_index(inplace=True)

# %%
plt.figure(figsize=(10,5))
plt.plot(dt_azad1398_income_u_gp.index, dt_azad1398_income_u_gp['income_s_y'], label=1398)
plt.plot(dt_azad1399_income_u_gp.index, dt_azad1399_income_u_gp['income_s_y'], label=1399)
plt.plot(dt_azad1400_income_u_gp.index, dt_azad1400_income_u_gp['income_s_y'], label=1400)
plt.plot(dt_azad1401_income_u_gp.index, dt_azad1401_income_u_gp['income_s_y'], label=1401)
plt.tight_layout()
plt.legend()
plt.show()

# %%
dt_azad1398_income_u_gp['real_income'] = dt_azad1398_income_u_gp['income_s_y'] * (base_year_cost / base_year_cost_u).values[0]
dt_azad1399_income_u_gp['real_income'] = dt_azad1399_income_u_gp['income_s_y'] * (base_year_cost / year_1399_cost_u).values[0]
dt_azad1400_income_u_gp['real_income'] = dt_azad1400_income_u_gp['income_s_y'] * (base_year_cost / year_1400_cost_u).values[0]
dt_azad1401_income_u_gp['real_income'] = dt_azad1401_income_u_gp['income_s_y'] * (base_year_cost / year_1401_cost_u).values[0]

# %%
plt.figure(figsize=(10,5))
plt.plot(dt_azad1398_income_u_gp.index, dt_azad1398_income_u_gp['real_income'], label=1398)
plt.plot(dt_azad1399_income_u_gp.index, dt_azad1399_income_u_gp['real_income'], label=1399)
plt.plot(dt_azad1400_income_u_gp.index, dt_azad1400_income_u_gp['real_income'], label=1400)
plt.plot(dt_azad1401_income_u_gp.index, dt_azad1401_income_u_gp['real_income'], label=1401)
plt.tight_layout()
plt.legend()
plt.show()

# %%
dt_azad1401_income_u_gp_part1 = dt_azad1401_income_u_gp[dt_azad1401_income_u_gp['real_income'] < dt_azad1401_income_u_gp['real_income'].quantile(0.8)]
dt_azad1400_income_u_gp_part1 = dt_azad1400_income_u_gp[dt_azad1400_income_u_gp['real_income'] < dt_azad1400_income_u_gp['real_income'].quantile(0.8)]
dt_azad1399_income_u_gp_part1 = dt_azad1399_income_u_gp[dt_azad1399_income_u_gp['real_income'] < dt_azad1399_income_u_gp['real_income'].quantile(0.8)]
dt_azad1398_income_u_gp_part1 = dt_azad1398_income_u_gp[dt_azad1398_income_u_gp['real_income'] < dt_azad1398_income_u_gp['real_income'].quantile(0.8)]

# %%
plt.figure(figsize=(10,5))
fig ,ax = plt.subplots(2,1, figsize=(10,5))
ax = ax.flatten()

ax[0].plot(dt_azad1398_income_u_gp_part1.index, dt_azad1398_income_u_gp_part1['income_s_y'], label=1398)
ax[0].plot(dt_azad1399_income_u_gp_part1.index, dt_azad1399_income_u_gp_part1['income_s_y'], label=1399)
ax[0].plot(dt_azad1400_income_u_gp_part1.index, dt_azad1400_income_u_gp_part1['income_s_y'], label=1400)
ax[0].plot(dt_azad1401_income_u_gp_part1.index, dt_azad1401_income_u_gp_part1['income_s_y'], label=1401)
ax[0].legend()

ax[1].plot(dt_azad1398_income_u_gp_part1.index, dt_azad1398_income_u_gp_part1['real_income'], label=1398)
ax[1].plot(dt_azad1399_income_u_gp_part1.index, dt_azad1399_income_u_gp_part1['real_income'], label=1399)
ax[1].plot(dt_azad1400_income_u_gp_part1.index, dt_azad1400_income_u_gp_part1['real_income'], label=1400)
ax[1].plot(dt_azad1401_income_u_gp_part1.index, dt_azad1401_income_u_gp_part1['real_income'], label=1401)
ax[1].legend()

plt.show()

# %%
dt_mozd1401_u_income = pd.read_excel('U1401.xlsx', sheet_name='U1401P4S01')
dt_mozd1401_u_income_gp = dt_mozd1401_u_income.groupby(['Address', 'member']).agg({'netincome_w_y': 'sum'})
dt_mozd1401_u_income_gp.sort_values(by='netincome_w_y', inplace=True)
dt_mozd1401_u_income_gp.reset_index(inplace=True)

# %%
dt_mozd1400_u_income = pd.read_excel('U1400.xlsx', sheet_name='U1400P4S01')
dt_mozd1400_u_income_gp = dt_mozd1400_u_income.groupby(['Address', 'member']).agg({'netincome_w_y': 'sum'})
dt_mozd1400_u_income_gp.sort_values(by='netincome_w_y', inplace=True)
dt_mozd1400_u_income_gp.reset_index(inplace=True)

# %%
dt_mozd1399_u_income = pd.read_excel('U99.xlsx', sheet_name='U99P4S01')
dt_mozd1399_u_income_gp = dt_mozd1399_u_income.groupby(['Address', 'member']).agg({'netincome_w_y': 'sum'})
dt_mozd1399_u_income_gp.sort_values(by='netincome_w_y', inplace=True)
dt_mozd1399_u_income_gp.reset_index(inplace=True)

# %%
dt_mozd1398_u_income = pd.read_excel('U98.xlsx', sheet_name='U98P4S01')
dt_mozd1398_u_income_gp = dt_mozd1398_u_income.groupby(['Address', 'member']).agg({'netincome_w_y': 'sum'})
dt_mozd1398_u_income_gp.sort_values(by='netincome_w_y', inplace=True)
dt_mozd1398_u_income_gp.reset_index(inplace=True)

# %%
dt_mozd1398_u_income_gp['real_income'] = dt_mozd1398_u_income_gp['netincome_w_y'] * (base_year_cost / base_year_cost).values[0]
dt_mozd1399_u_income_gp['real_income'] = dt_mozd1399_u_income_gp['netincome_w_y'] * (base_year_cost / year_1399_cost).values[0]
dt_mozd1400_u_income_gp['real_income'] = dt_mozd1400_u_income_gp['netincome_w_y'] * (base_year_cost / year_1400_cost).values[0]
dt_mozd1401_u_income_gp['real_income'] = dt_mozd1401_u_income_gp['netincome_w_y'] * (base_year_cost / year_1401_cost).values[0]

# %%
plt.figure(figsize=(10,5))
plt.plot(dt_mozd1398_u_income_gp.index, dt_mozd1398_u_income_gp['netincome_w_y'], label=1398)
plt.plot(dt_mozd1399_u_income_gp.index, dt_mozd1399_u_income_gp['netincome_w_y'], label=1399)
plt.plot(dt_mozd1400_u_income_gp.index, dt_mozd1400_u_income_gp['netincome_w_y'], label=1400)
plt.plot(dt_mozd1401_u_income_gp.index, dt_mozd1401_u_income_gp['netincome_w_y'], label=1401)
plt.tight_layout()
plt.legend()
plt.show()

# %%
dt_mozd1401_u_income_gp = dt_mozd1401_u_income_gp[dt_mozd1401_u_income_gp['real_income'] < dt_mozd1401_u_income_gp['real_income'].quantile(0.8)]
dt_mozd1400_u_income_gp = dt_mozd1400_u_income_gp[dt_mozd1400_u_income_gp['real_income'] < dt_mozd1400_u_income_gp['real_income'].quantile(0.8)]
dt_mozd1399_u_income_gp = dt_mozd1399_u_income_gp[dt_mozd1399_u_income_gp['real_income'] < dt_mozd1399_u_income_gp['real_income'].quantile(0.8)]
dt_mozd1398_u_income_gp = dt_mozd1398_u_income_gp[dt_mozd1398_u_income_gp['real_income'] < dt_mozd1398_u_income_gp['real_income'].quantile(0.8)]

# %%
plt.figure(figsize=(10,5))
fig ,ax = plt.subplots(2,1, figsize=(10,5))
ax = ax.flatten()
ax[0].plot(dt_mozd1398_u_income_gp.index, dt_mozd1398_u_income_gp['netincome_w_y'], label=1398)
ax[0].plot(dt_mozd1399_u_income_gp.index, dt_mozd1399_u_income_gp['netincome_w_y'], label=1399)
ax[0].plot(dt_mozd1400_u_income_gp.index, dt_mozd1400_u_income_gp['netincome_w_y'], label=1400)
ax[0].plot(dt_mozd1401_u_income_gp.index, dt_mozd1401_u_income_gp['netincome_w_y'], label=1401)
ax[0].legend()

ax[1].plot(dt_mozd1398_u_income_gp.index, dt_mozd1398_u_income_gp['real_income'], label=1398)
ax[1].plot(dt_mozd1399_u_income_gp.index, dt_mozd1399_u_income_gp['real_income'], label=1399)
ax[1].plot(dt_mozd1400_u_income_gp.index, dt_mozd1400_u_income_gp['real_income'], label=1400)
ax[1].plot(dt_mozd1401_u_income_gp.index, dt_mozd1401_u_income_gp['real_income'], label=1401)
ax[1].legend()
plt.show()
