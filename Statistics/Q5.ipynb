# %%
import pandas as pd
import matplotlib.pyplot as plt,seaborn as sns

# %%
# پوشاک و کفش
R98_kafsh = pd.read_excel('R98.xlsx', sheet_name='R98P3S03')
U98_kafsh = pd.read_excel('U98.xlsx', sheet_name='U98P3S03')
R99_kafsh = pd.read_excel('R99.xlsx', sheet_name='R99P3S03')
U99_kafsh = pd.read_excel('U99.xlsx', sheet_name='U99P3S03')
R1400_kafsh = pd.read_excel('R1400.xlsx', sheet_name='R1400P3S03')
U1400_kafsh = pd.read_excel('U1400.xlsx', sheet_name='U1400P3S03')
R1401_kafsh = pd.read_excel('R1401.xlsx', sheet_name='R1401P3S03')
U1401_kafsh = pd.read_excel('U1401.xlsx', sheet_name='U1401P3S03')

# %%
concat_kafsh_R = pd.concat([R98_kafsh, R99_kafsh, R1400_kafsh, R1401_kafsh])
concat_kafsh_U = pd.concat([U98_kafsh, U99_kafsh, U1400_kafsh, U1401_kafsh])

# %%
fig, axes = plt.subplots(4, 2, figsize=(10,10))
sns.heatmap(R98_kafsh.corr().abs(), annot=True, ax=axes[0,0])
sns.heatmap(U98_kafsh.corr().abs(), annot=True, ax=axes[0,1])
sns.heatmap(R99_kafsh.corr().abs(), annot=True, ax=axes[1,0])
sns.heatmap(U99_kafsh.corr().abs(), annot=True, ax=axes[1,1])
sns.heatmap(R1400_kafsh.corr().abs(), annot=True, ax=axes[2,0])
sns.heatmap(U1400_kafsh.corr().abs(), annot=True, ax=axes[2,1])
sns.heatmap(R1401_kafsh.corr().abs(), annot=True, ax=axes[3,0])
sns.heatmap(U1401_kafsh.corr().abs(), annot=True, ax=axes[3,1])

plt.tight_layout()
plt.show()

# %%
fig, axes = plt.subplots(1, 2, figsize=(8, 4))


sns.heatmap(concat_kafsh_R.corr().abs(), annot=True, ax=axes[0])

sns.heatmap(concat_kafsh_U.corr().abs(), annot=True, ax=axes[1])


plt.tight_layout()
plt.show()

# %%
# خوراکی
R98_khoraki = pd.read_excel('R98.xlsx', sheet_name='R98P3S01')
U98_khoraki = pd.read_excel('U98.xlsx', sheet_name='U98P3S01')
R99_khoraki = pd.read_excel('R99.xlsx', sheet_name='R99P3S01')
U99_khoraki = pd.read_excel('U99.xlsx', sheet_name='U99P3S01')
R1400_khoraki = pd.read_excel('R1400.xlsx', sheet_name='R1400P3S01')
U1400_khoraki = pd.read_excel('U1400.xlsx', sheet_name='U1400P3S01')
R1401_khoraki = pd.read_excel('R1401.xlsx', sheet_name='R1401P3S01')
U1401_khoraki = pd.read_excel('U1401.xlsx', sheet_name='U1401P3S01')

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
R98_khoraki['gram'] = le.fit_transform(R98_khoraki['gram'])
R98_khoraki.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 516798 entries, 0 to 516797
# Data columns (total 7 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   Address    516798 non-null  int64
#  1   code       516798 non-null  int64
#  2   purchased  516798 non-null  int64
#  3   gram       516798 non-null  int64
#  4   kilogram   395555 non-null  float64
#  5   price      468830 non-null  float64
#  6   value      516797 non-null  float64
# dtypes: float64(3), int64(4)
# memory usage: 27.6 MB

# %%
concat_khoraki_R = pd.concat([R98_khoraki, R99_khoraki, R1400_khoraki, R1401_khoraki])
concat_khoraki_U = pd.concat([U98_khoraki, U99_khoraki, U1400_khoraki, U1401_khoraki])

# %%
fig, axes = plt.subplots(4, 2, figsize=(20,20))
sns.heatmap(R98_khoraki.corr().abs(), annot=True, ax=axes[0,0])
sns.heatmap(U98_khoraki.corr().abs(), annot=True, ax=axes[0,1])
sns.heatmap(R99_khoraki.corr().abs(), annot=True, ax=axes[1,0])
sns.heatmap(U99_khoraki.corr().abs(), annot=True, ax=axes[1,1])
sns.heatmap(R1400_khoraki.corr().abs(), annot=True, ax=axes[2,0])
sns.heatmap(U1400_khoraki.corr().abs(), annot=True, ax=axes[2,1])
sns.heatmap(R1401_khoraki.corr().abs(), annot=True, ax=axes[3,0])
sns.heatmap(U1401_khoraki.corr().abs(), annot=True, ax=axes[3,1])
plt.tight_layout()
plt.show()

# %%
fig, axes = plt.subplots(1, 2, figsize=(15, 8))
sns.heatmap(concat_khoraki_R.corr().abs(), annot=True, ax=axes[0])
sns.heatmap(concat_khoraki_U.corr().abs(), annot=True, ax=axes[1])
plt.tight_layout()
plt.show()

# %%
# مسکن
R98_maskan = pd.read_excel('R98.xlsx', sheet_name='R98P3S04')
U98_maskan = pd.read_excel('U98.xlsx', sheet_name='U98P3S04')
R99_maskan = pd.read_excel('R99.xlsx', sheet_name='R99P3S04')
U99_maskan = pd.read_excel('U99.xlsx', sheet_name='U99P3S04')
R1400_maskan = pd.read_excel('R1400.xlsx', sheet_name='R1400P3S04')
U1400_maskan = pd.read_excel('U1400.xlsx', sheet_name='U1400P3S04')
R1401_maskan = pd.read_excel('R1401.xlsx', sheet_name='R1401P3S04')
U1401_maskan = pd.read_excel('U1401.xlsx', sheet_name='U1401P3S04')

# %%
concat_maskan_R = pd.concat([R98_maskan, R99_maskan, R1400_maskan, R1401_maskan])
concat_maskan_U = pd.concat([U98_maskan, U99_maskan, U1400_maskan, U1401_maskan])

# %%
fig, axes = plt.subplots(4, 2, figsize=(20,20))
sns.heatmap(R98_maskan.corr().abs(), annot=True, ax=axes[0,0])
sns.heatmap(U98_maskan.corr().abs(), annot=True, ax=axes[0,1])
sns.heatmap(R99_maskan.corr().abs(), annot=True, ax=axes[1,0])
sns.heatmap(U99_maskan.corr().abs(), annot=True, ax=axes[1,1])
sns.heatmap(R1400_maskan.corr().abs(), annot=True, ax=axes[2,0])
sns.heatmap(U1400_maskan.corr().abs(), annot=True, ax=axes[2,1])
sns.heatmap(R1401_maskan.corr().abs(), annot=True, ax=axes[3,0])
sns.heatmap(U1401_maskan.corr().abs() ,annot=True, ax=axes[3,1])



plt.tight_layout()
plt.show()

# %%
fig, axes = plt.subplots(1, 2, figsize=(14, 6))
sns.heatmap(concat_maskan_R.corr().abs(), annot=True, ax=axes[0])
sns.heatmap(concat_maskan_U.corr().abs(), annot=True, ax=axes[1])
plt.tight_layout()
plt.show()

# %%
# بهداشتی
R98_behdashti = pd.read_excel('R98.xlsx', sheet_name='R98P3S06')
U98_behdashti = pd.read_excel('U98.xlsx', sheet_name='U98P3S06')
R99_behdashti = pd.read_excel('R99.xlsx', sheet_name='R99P3S06')
U99_behdashti = pd.read_excel('U99.xlsx', sheet_name='U99P3S06')
R1400_behdashti = pd.read_excel('R1400.xlsx', sheet_name='R1400P3S06')
U1400_behdashti = pd.read_excel('U1400.xlsx', sheet_name='U1400P3S06')
R1401_behdashti = pd.read_excel('R1401.xlsx', sheet_name='R1401P3S06')
U1401_behdashti = pd.read_excel('U1401.xlsx', sheet_name='U1401P3S06')

# %%
concat_behdashti_R = pd.concat([R98_behdashti, R99_behdashti, R1400_behdashti, R1401_behdashti])
concat_behdashti_U = pd.concat([U98_behdashti, U99_behdashti, U1400_behdashti, U1401_behdashti])

# %%
fig, axes = plt.subplots(4, 2, figsize=(20,20))
sns.heatmap(R98_behdashti.corr().abs(), annot=True, ax=axes[0,0])
sns.heatmap(U98_behdashti.corr().abs(), annot=True, ax=axes[0,1])
sns.heatmap(R99_behdashti.corr().abs(), annot=True, ax=axes[1,0])
sns.heatmap(U99_behdashti.corr().abs(), annot=True, ax=axes[1,1])
sns.heatmap(R1400_behdashti.corr().abs(), annot=True, ax=axes[2,0])
sns.heatmap(U1400_behdashti.corr().abs(), annot=True, ax=axes[2,1])
sns.heatmap(R1401_behdashti.corr().abs(), annot=True, ax=axes[3,0])
sns.heatmap(U1401_behdashti.corr().abs(), annot=True, ax=axes[3,1])
plt.tight_layout()
plt.show()

# %%
fig, axes = plt.subplots(1, 2, figsize=(14, 6))
sns.heatmap(concat_behdashti_R.corr().abs(), annot=True, ax=axes[0])
sns.heatmap(concat_behdashti_U.corr().abs(), annot=True, ax=axes[1])
plt.tight_layout()
plt.show()

# %%
R1401_bazneshstgi = pd.read_excel('R1401.xlsx', sheet_name='R1401P4S03')

# %%
R1401_bazneshstgi
# Out:
#            Address  member  income_pension  income_rent  income_interest  \
# 0      20001384026       1               0            0         54000000
# 1      20001384027       1               0            0          5000000
# 2      20001384031       1               0            0          4700000
# 3      20001384035       1               0            0          7500000
# 4      20001384038       1               0            0         17000000
# ...            ...     ...             ...          ...              ...
# 26936  23006709629       2               0            0                0
# 26937  23006709632       1       435000000            0                0
# 26938  23006709635       1               0            0                0
# 26939  23006709638       1               0            0                0
# 26940  23006709641       1       435000000            0        500000000
#
#        income_aid  income_resale  income_transfer  Fasl  year  DYCOL00
# ...

# %%
R1401_bazneshstgi['income_pension']
# Out:
# 0                0
# 1                0
# 2                0
# 3                0
# 4                0
#            ...
# 26936            0
# 26937    435000000
# 26938            0
# 26939            0
# 26940    435000000
# Name: income_pension, Length: 26941, dtype: int64
